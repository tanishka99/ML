# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishka99/ML/blob/master/comp_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
#checking version
cv2.__version__
# Out:
# '3.4.3'

# %%
#img read,#image name,image property
img=cv2.imread('logoo.png',1)
img1=cv2.imread('logoo.png',0)
img2=cv2.imread('logoo.png',-1)
#1 means img in same color channel--GRB OR RGB
#0 means no color channel tha is black and white ----(gray img) in opencv
# -1 maintains img transparency---

# %%
img

# %%
#print shape
img.shape
# Out:
# (245, 465, 3)

# %%
#type
type(img)




#IMG OPERATIONS

#split into BGR
x,y,z=cv2.split(img)

# %%
#to display img
#plt.imshow(x)
#cv2_imshow(img[0:130,0:150])   #for cropping the image 
#cv2_imshow(y)
#cv2_imshow(z)



#to draw a line in img
cv2.line(img,(0,0),(200,230),(0,0,255),3)
cv2.rectangle(img,(50,50),(100,110),(255,0,0),-1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=465x245 at 0x7F3845E8DDA0>

# %%
#wait for window to close
cv2.waitKey(0)   #mili/micro secnd
# Out:
# -1

# %%
#IMG OPERATIONS

#split into BGR
x,y,z=split(img)
